# %%
from astropy.table import Table 
import numpy as np
import matplotlib.pyplot as plt

# %%
input_inc20 = "/home/user/THESIS/MODELS_THESIS/INC/CGal_4_20_0.01/CGal_4_20_0.01_params.txt"
inc20 = Table.read(input_inc20,format='ascii')
inc20_i = np.mean(inc20["INC"])

rec_inc20 = "/home/user/THESIS/new_tests_inclination/CGal_4_20_0.01_E_nau/errors.txt"
inc20r = Table.read(rec_inc20,format='ascii')
inc20_r = inc20r[np.char.find(inc20r['Parameter'], 'inc') >= 0]
print(inc20_r["Median"])

input_inc30 = "/home/user/THESIS/MODELS_THESIS/INC/CGal_4_30_0.01/CGal_4_30_0.01_params.txt"
inc30 = Table.read(input_inc30,format='ascii')
inc30_i = np.mean(inc30["INC"])

rec_inc30 = "/home/user/THESIS/new_tests_inclination/CGal_4_30_0.01_E_nau/errors.txt"
inc30r = Table.read(rec_inc30,format='ascii')
inc30_r = inc30r[np.char.find(inc30r['Parameter'], 'inc') >= 0]
print(inc30_r["Median"])

input_inc40 = "/home/user/THESIS/MODELS_THESIS/INC/CGal_4_40_0.01/CGal_4_40_0.01_params.txt"
inc40 = Table.read(input_inc40,format='ascii')
inc40_i = np.mean(inc40["INC"])

rec_inc40 = "/home/user/THESIS/new_tests_inclination/CGal_4_40_0.01_E_nau/errors.txt"
inc40r = Table.read(rec_inc40,format='ascii')
inc40_r = inc40r[np.char.find(inc40r['Parameter'], 'inc') >= 0]
print(inc40_r["Median"])

input_inc50 = "/home/user/THESIS/MODELS_THESIS/INC/CGal_4_50_0.01/CGal_4_50_0.01_params.txt"
inc50 = Table.read(input_inc50,format='ascii')
inc50_i = np.mean(inc50["INC"])         

rec_inc50 = "/home/user/THESIS/new_tests_inclination/CGal_4_50_0.01_E_nau/errors.txt"
inc50r = Table.read(rec_inc50,format='ascii')
inc50_r = inc50r[np.char.find(inc50r['Parameter'], 'inc') >= 0]
print(inc50_r["Median"])

input_inc60 = "/home/user/THESIS/MODELS_THESIS/INC/CGal_4_60_0.01/CGal_4_60_0.01_params.txt"
inc60 = Table.read(input_inc60,format='ascii')
inc60_i = np.mean(inc60["INC"])

rec_inc60 = "/home/user/THESIS/new_tests_inclination/CGal_4_60_0.01_E_nau/errors.txt"
inc60r = Table.read(rec_inc60,format='ascii')
inc60_r = inc60r[np.char.find(inc60r['Parameter'], 'inc') >= 0]
print(inc60_r["Median"])

input_inc70 = "/home/user/THESIS/MODELS_THESIS/INC/CGal_4_70_0.01/CGal_4_70_0.01_params.txt"        
inc70 = Table.read(input_inc70,format='ascii')
inc70_i = np.mean(inc70["INC"])

rec_inc70 = "/home/user/THESIS/new_tests_inclination/CGal_4_70_0.01_E_nau/errors.txt"
inc70r = Table.read(rec_inc70,format='ascii')
inc70_r = inc70r[np.char.find(inc70r['Parameter'], 'inc') >= 0]
print(inc70_r["Median"])

input_inc80 = "/home/user/THESIS/MODELS_THESIS/INC/CGal_4_80_0.01/CGal_4_80_0.01_params.txt"
inc80 = Table.read(input_inc80,format='ascii')
inc80_i = np.mean(inc80["INC"]) 

rec_inc80 = "/home/user/THESIS/new_tests_inclination/CGal_4_80_0.01_E_nau/errors.txt"
inc80r = Table.read(rec_inc80,format='ascii')
inc80_r = inc80r[np.char.find(inc80r['Parameter'], 'inc') >= 0]
print(inc80_r["Median"])

input_inc85 = "/home/user/THESIS/MODELS_THESIS/INC/CGal_4_85_0.01/CGal_4_85_0.01_params.txt"
inc85 = Table.read(input_inc85,format='ascii')
inc85_i = np.mean(inc85["INC"]) 

rec_inc85 = "/home/user/THESIS/new_tests_inclination/CGal_4_85_0.01_E_nau/errors.txt"
inc85r = Table.read(rec_inc85,format='ascii')
inc85_r = inc85r[np.char.find(inc85r['Parameter'], 'inc') >= 0]
print(inc85_r["Median"])
# Out:
#   Median
# ---------
# 26.348078
#   Median
# ---------
# 31.985024
#   Median
# ---------
# 41.358025
#   Median
# ---------
# 52.190456
#   Median
# ---------
# 61.351107
#   Median
# ---------
# 71.306471
#   Median
# ---------
# 82.484154
#  Median
# --------
# 88.71636

# %%
col = plt.cm.tab10(np.linspace(0, 1, 10))  # Use tab10 for distinct colors
imput = [20,30,40,50,60,70,80,85]
plt.figure(figsize=(10, 6))
plt.errorbar(20, inc20_r['Median'], capsize=5, fmt='o', markersize=5,yerr=[inc20_r['Error_Low'], inc20_r['Error_Up']], color=col[0])
plt.errorbar(30, inc30_r['Median'], capsize=5, fmt='o', markersize=5,yerr=[inc30_r['Error_Low'], inc30_r['Error_Up']], color=col[1])
plt.errorbar(40, inc40_r['Median'], capsize=5, fmt='o', markersize=5,yerr=[inc40_r['Error_Low'], inc40_r['Error_Up']], color=col[2])
plt.errorbar(50, inc50_r['Median'], capsize=5, fmt='o', markersize=5,yerr=[inc50_r['Error_Low'], inc50_r['Error_Up']], color=col[3])
plt.errorbar(60, inc60_r['Median'], capsize=5, fmt='o', markersize=5,yerr=[inc60_r['Error_Low'], inc60_r['Error_Up']], color=col[4])
plt.errorbar(70, inc70_r['Median'], capsize=5, fmt='o', markersize=5,yerr=[inc70_r['Error_Low'], inc70_r['Error_Up']], color=col[5])
plt.errorbar(80, inc80_r['Median'], capsize=5, fmt='o', markersize=5,yerr=[inc80_r['Error_Low'], inc80_r['Error_Up']], color=col[6])
plt.errorbar(85, inc85_r['Median'], capsize=5, fmt='o', markersize=5,yerr=[inc85_r['Error_Low'], inc85_r['Error_Up']], color=col[7])

plt.plot(imput, imput, 'k--')
plt.xlabel('Cube inclination')
plt.ylabel('Recovered inclination')
plt.title('Input vs Recovered Values for Inclinations')
plt.tight_layout()
plt.savefig(f'inc_compare.pdf',bbox_inches='tight')
# Show the plot
plt.show()
